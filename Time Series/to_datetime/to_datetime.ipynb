# %%
import pandas as pd

dates = ['2017-01-05 3:15:00 PM', 'Jan 5 2017 15:15:00', '01/05/2017', '2017.01.05', '2017/01/05', '20170105', 'abbjsdfjdja']

pd.to_datetime(dates, errors = 'coerce')
# Out:
# C:\Users\Smoke Nandos\AppData\Local\Temp\ipykernel_23956\3900947596.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(dates, errors = 'coerce')
# DatetimeIndex(['2017-01-05 15:15:00', '2017-01-05 15:15:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                                'NaT'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime('5/1/2017', dayfirst = True)
# Out:
# Timestamp('2017-01-05 00:00:00')

# %%
t = 1775149689
dt = pd.to_datetime([t], unit = 's')
dt
# Out:
# DatetimeIndex(['2026-04-02 17:08:09'], dtype='datetime64[ns]', freq=None)

# %%
dt.view('int64')
# Out:
# array([1775149689000000000], dtype=int64)
